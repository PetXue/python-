# %% [markdown]
# # 第一章：初始python
# ## print 输出函数
# ## 语法结构：
# print(输出内容)
# print()函数完整语法格式：
# print(*values,sep=" ",end="\n",file=None,flush=False)

# %%
print(123)
# Out:
# 123

# %%
print("hello world")
# Out:
# hello world

# %%
print(1,2,3,4)#1 2 3 4 默认分隔符为空格
print(1,2,3,4,sep="->")# 分隔符改为了箭头->
# Out:
# 1 2 3 4
# 1->2->3->4

# %%
print(1,2,3)#默认换行 \n
print(1,2,3)
# Out:
# 1 2 3
# 1 2 3

# %%
print(1,2,3 ,end="\t")#\t 为制表符，为一个tab的大小
print(1,2,3)
# Out:
# 1 2 3	1 2 3

# %%
#打开名为”报错.txt“的文件，以追加模式（”a“）打开 w 为写入 会覆盖原文本
#如果文件不存在，会自动创建
f = open("报错.txt","a")
print("hello world ",file=f)#将字符串”hello world “写入文件中，使用print函数，并指定输出目标为文件f
f.close()#关闭文件，确保所有写入的内容保存到文件中

# %%
#使用with 语句打开文件”报错.txt“,以追加模式（”a“）打开
#with 语句可以确保文件在操作完成后自动关闭，避免手动关闭
with open("报错.txt",'a') as f:
  print("hello worldd",file=f)#文件会在with语句结束时自动关闭

# %% [markdown]
# # input 输入函数
# input（）

# %%
input()
# Out:
# '123'

# %% [markdown]
# # 格式化输出
#
# ## 含义
# 给定一个模板，按照模板输出内容。
# ## 格式符号
# 格式化输出使用 %和不同的字符连用，不同类型的数据需要使用不同的格式化字符。
# 常用格式化字符及其含义
# | 格式化字符 |  含义 |
# |---|---|
# | %c | 字符 |
# | %s | 字符串 |
# | %d | 十进制整数 |
# | %f | 浮点数 |
#
# ## 基本格式化输出：使用%
# 例子：
# print(我的名字是%s，年龄是%d岁%("θ1"，18)）
# ## format()格式化输出
# 例子:
# print("我的名字是：{，年龄为：{}岁".format("01"，18)）
#
# ## f表达式格式化输出
#
# 例子：
# name,age ="01",18
# print(f"名字是{name},年龄是{age}岁")

# %%
print('我的名字是%s,年龄是%d岁'%("θ1",18))
print('我的名字是:{},年龄是{}岁'.format("θ1",18))
name,age="01",18
print(f"名字是{name},今年{age}岁")
# Out:
# 我的名字是θ1,年龄是18岁
# 我的名字是:θ1,年龄是18岁
# 名字是01,今年18岁

# %% [markdown]
# ## 变量
# + 变量是将数据在内存中存储后给定的一个名称，这个名称就是变量。
# + 变量名是没有类型的，类型只存在于对象中，比那辆知识引用对象。
# + python为动态解释型语言，在赋值操作时，类型是在运行过程中自动决定的。
# ## 对象
# + 对象是有类型的。
# + 对象是分配的一块内存空间，用来表示它的值。
# + python对象的三要素：
#   - id ：对象的唯一标识符
#   - type : 对象的类型。
#   - value ：对象的值。
#
# ## 变量的命名
# + 变量名只能由数字、字母和（下划线）组成。
# + 变量名不能以数字开头。
# + 变量名不能是Python关键字。
# + 变量名是区分大小写的。

# %%
#python关键字
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a = 1# 定义变量
print(a)
print (id(a))
# Out:
# 1
# 140733849443248

# %%
epoch = 100
acc =0.8
print(f"训练的总轮数为{epoch}，得到的acc为{acc} ")
# Out:
# 训练的总轮数为100，得到的acc为0.8

# %% [markdown]
# ## input()函数
# ` input（）`是Python中用于从用户获取输入的函数。它会在控制台显示提示信息，并等待用户输入。用户输入的内容会以字符串形
# 回。
# ## 基本用法
# ```python
# user_input=input("请输入一些内容：")
# print("你输入的内容是:"，user_input)
# ```

# %%
b=input("请输入一些内容：")
print("你输入的内容是:",b)
print(type(b))
# Out:
# 你输入的内容是: fafa

# %%
age=int(input("请输入一些内容："))# 类型的强制转换
print("你输入的内容是:",age)
print(type(age))
